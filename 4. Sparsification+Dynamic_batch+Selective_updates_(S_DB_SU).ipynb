# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# --------- Minimal MLP Model ----------
class MinimalMLPModel(nn.Module):
    def __init__(self):
        super(MinimalMLPModel, self).__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        return self.net(x)

# --------- Sparsification Utility ----------
def sparsify_state_dict(state_dict, compression_ratio=0.1):
    sparse_state = {}
    for k, v in state_dict.items():
        flat = v.view(-1)
        k_val = int(len(flat) * compression_ratio)
        if k_val == 0:
            sparse_state[k] = torch.zeros_like(v)
            continue
        _, idxs = torch.topk(flat.abs(), k_val)
        mask = torch.zeros_like(flat)
        mask[idxs] = 1.0
        sparse_flat = flat * mask
        sparse_state[k] = sparse_flat.view(v.shape)
    return sparse_state

# --------- Federated Training Utilities ----------
def train(model, loader, optimizer, criterion, epochs=1):
    model.train()
    for _ in range(epochs):
        for x, y in loader:
            optimizer.zero_grad()
            loss = criterion(model(x), y)
            loss.backward()
            optimizer.step()

def evaluate(model, loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for x, y in loader:
            preds = model(x).argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    return correct / total

def similarity_score(state1, state2):
    norm_diff = 0.0
    norm_ref = 0.0
    for k in state1:
        diff = state1[k] - state2[k]
        norm_diff += torch.norm(diff).item()
        norm_ref += torch.norm(state2[k]).item()
    return 1 - (norm_diff / norm_ref)

# --------- Main Federated Learning Process ----------
def federated_training(
        optimizer_name='adam',
        num_clients=10,
        max_batch_size=100,
        rounds=10,
        bandwidth_mb_per_s=20,
        compression_ratio=0.4
    ):
    client_powers = torch.rand(num_clients)
    max_power = client_powers.max()

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    full_dataset = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
    client_data = random_split(full_dataset, [len(full_dataset)//num_clients]*num_clients)

    global_model = MinimalMLPModel()
    criterion = nn.CrossEntropyLoss()

    global_accs, comm_volumes, agg_times, net_times, conv_speeds = [], [], [], [], []
    prev_global_acc = 0.0

    total_params = sum(p.numel() for p in global_model.parameters())

    print(f"\n=== Running Federated Training with {optimizer_name.upper()} ===")
    for rnd in range(1, rounds+1):
        print(f"\n=== Round {rnd} ===")
        selected_states = []
        inclusion_threshold = 0.65 if rnd > 1 else 0.20

        for i in range(num_clients):
            ratio = (client_powers[i] / max_power).item()
            batch_size = max(1, int(ratio * max_batch_size))
            print(f"Client {i}: power={client_powers[i]:.3f} → batch_size={batch_size}")

            local_model = MinimalMLPModel()
            local_model.load_state_dict(global_model.state_dict())

            if optimizer_name == 'adam':
                optimizer = optim.Adam(local_model.parameters(), lr=0.001)
            elif optimizer_name == 'sgd':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.0)
            elif optimizer_name == 'nag':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.9, nesterov=True)
            elif optimizer_name == 'mgd':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.99)
            else:
                raise ValueError(f"Unknown optimizer: {optimizer_name}")

            train_loader = DataLoader(client_data[i], batch_size=batch_size, shuffle=True)
            train(local_model, train_loader, optimizer, criterion, epochs=1)

            sim = similarity_score(local_model.state_dict(), global_model.state_dict())
            print(f"  → similarity with global model: {sim:.2%}", end='')

            if sim > inclusion_threshold:
                print(" ✅ included")
                sparse_state = sparsify_state_dict(local_model.state_dict(), compression_ratio)
                selected_states.append(sparse_state)
            else:
                print(" ❌ excluded")

        sent_clients = len(selected_states)
        comm_mb = sent_clients * total_params * compression_ratio * 4 / 1e6
        net_time = comm_mb / bandwidth_mb_per_s

        start = time.perf_counter()
        new_state = {}
        for key in global_model.state_dict().keys():
            stack = torch.stack([state[key] for state in selected_states], dim=0)
            new_state[key] = stack.mean(dim=0)
        global_model.load_state_dict(new_state)
        agg_time = time.perf_counter() - start

        test_ds = datasets.MNIST(root="./data", train=False, download=True, transform=transform)
        test_loader = DataLoader(test_ds, batch_size=64)
        global_acc = evaluate(global_model, test_loader)

        global_accs.append(global_acc)
        comm_volumes.append(comm_mb)
        net_times.append(net_time)
        agg_times.append(agg_time)
        if rnd > 1:
            conv_speeds.append(global_acc - prev_global_acc)
        prev_global_acc = global_acc

        print(f"\nGlobal Accuracy         : {global_acc:.2%}")
        print(f"Selected clients        : {sent_clients}/{num_clients}")
        print(f"Comm Volume             : {comm_mb:.2f} MB")
        print(f"Simulated Net Time      : {net_time:.2f} s")
        print(f"Server Aggregation Time : {agg_time:.4f} s")

    rounds_idx = list(range(1, rounds+1))


if __name__ == '__main__':
    for opt in ['sgd', 'nag', 'mgd', 'adam']:
        federated_training(
            optimizer_name=opt,
            num_clients=10,
            max_batch_size=100,
            rounds=10,
            bandwidth_mb_per_s=20,
            compression_ratio=0.4  # 10% sparsity
        )
# Out:
# === Running Federated Training with SGD ===
#
# === Round 1 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 96.07% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 48.82% ✅ included
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 48.54% ✅ included
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 88.45% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.55% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.83% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 96.97% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 94.66% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 94.17% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 95.94% ✅ included
#
# Global Accuracy         : 75.02%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 2 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 95.19% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 51.47% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 51.54% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 87.44% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.18% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.34% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 96.24% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 93.56% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 93.10% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 95.07% ✅ included
#
# Global Accuracy         : 72.16%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0013 s
#
# === Round 3 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 95.34% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 51.99% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 52.08% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 87.79% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.24% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.43% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 96.37% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 93.74% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 93.32% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 95.23% ✅ included
#
# Global Accuracy         : 74.66%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0012 s
#
# === Round 4 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 95.65% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 55.20% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 54.87% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 88.69% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.35% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.60% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 96.60% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 94.15% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 93.79% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 95.54% ✅ included
#
# Global Accuracy         : 76.80%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0011 s
#
# === Round 5 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 95.98% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 58.06% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 57.62% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 89.65% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.48% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.77% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 96.87% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 94.60% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 94.28% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 95.88% ✅ included
#
# Global Accuracy         : 78.42%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0011 s
#
# === Round 6 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 96.33% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 60.65% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 60.15% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 90.57% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.60% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 97.97% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 97.13% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 95.08% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 94.79% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 96.25% ✅ included
#
# Global Accuracy         : 79.73%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0014 s
#
# === Round 7 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 96.65% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 62.93% ❌ excluded
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 62.44% ❌ excluded
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 91.45% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.72% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 98.15% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 97.38% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 95.52% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 95.26% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 96.61% ✅ included
#
# Global Accuracy         : 80.95%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0015 s
#
# === Round 8 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 96.98% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 65.35% ✅ included
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 65.03% ✅ included
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 92.29% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 98.84% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 98.31% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 97.62% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 95.96% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 95.71% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 96.94% ✅ included
#
# Global Accuracy         : 84.13%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 9 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 97.73% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 71.03% ✅ included
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 70.85% ✅ included
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 94.30% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 99.08% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 98.71% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 98.21% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 96.98% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 96.83% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 97.70% ✅ included
#
# Global Accuracy         : 85.99%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 10 ===
# Client 0: power=0.341 → batch_size=36
#   → similarity with global model: 98.26% ✅ included
# Client 1: power=0.004 → batch_size=1
#   → similarity with global model: 75.31% ✅ included
# Client 2: power=0.008 → batch_size=1
#   → similarity with global model: 75.09% ✅ included
# Client 3: power=0.117 → batch_size=12
#   → similarity with global model: 95.62% ✅ included
# Client 4: power=0.935 → batch_size=100
#   → similarity with global model: 99.26% ✅ included
# Client 5: power=0.635 → batch_size=67
#   → similarity with global model: 99.00% ✅ included
# Client 6: power=0.443 → batch_size=47
#   → similarity with global model: 98.57% ✅ included
# Client 7: power=0.245 → batch_size=26
#   → similarity with global model: 97.67% ✅ included
# Client 8: power=0.232 → batch_size=24
#   → similarity with global model: 97.55% ✅ included
# Client 9: power=0.331 → batch_size=35
#   → similarity with global model: 98.23% ✅ included
#
# Global Accuracy         : 87.39%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0014 s
#
# === Running Federated Training with NAG ===
#
# === Round 1 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 82.37% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 44.11% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 51.14% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 86.59% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 88.09% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 47.73% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 86.20% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 54.59% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 84.97% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 80.01% ✅ included
#
# Global Accuracy         : 79.23%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0012 s
#
# === Round 2 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 88.35% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 60.31% ❌ excluded
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 67.18% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 90.50% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 91.40% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 63.60% ❌ excluded
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 90.29% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 70.20% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 89.63% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 87.09% ✅ included
#
# Global Accuracy         : 85.07%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 3 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 92.87% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 69.54% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 75.65% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 94.22% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 94.85% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 72.97% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 94.03% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 78.69% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 93.68% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 91.90% ✅ included
#
# Global Accuracy         : 88.42%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 4 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 95.73% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 77.59% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 82.89% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 96.56% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 96.94% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 80.18% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 96.52% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 85.26% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 96.19% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 95.05% ✅ included
#
# Global Accuracy         : 89.65%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 5 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 96.98% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 81.46% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 86.52% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 97.51% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 97.85% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 84.16% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 97.53% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 88.54% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 97.36% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 96.48% ✅ included
#
# Global Accuracy         : 90.36%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0015 s
#
# === Round 6 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 97.55% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 83.81% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 88.34% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 98.04% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 98.30% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 86.25% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 97.99% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 90.24% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 97.88% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 97.17% ✅ included
#
# Global Accuracy         : 90.78%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Round 7 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 97.93% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 85.54% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 89.56% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 98.32% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 98.46% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 87.74% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 98.30% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 91.48% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 98.20% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 97.59% ✅ included
#
# Global Accuracy         : 91.09%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0012 s
#
# === Round 8 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 98.13% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 86.65% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 90.40% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 98.40% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 98.64% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 88.84% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 98.47% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 92.13% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 98.33% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 97.76% ✅ included
#
# Global Accuracy         : 91.54%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0016 s
#
# === Round 9 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 98.28% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 87.50% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 91.01% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 98.53% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 98.77% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 89.56% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 98.58% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 92.61% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 98.45% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 97.95% ✅ included
#
# Global Accuracy         : 91.67%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0014 s
#
# === Round 10 ===
# Client 0: power=0.544 → batch_size=70
#   → similarity with global model: 98.36% ✅ included
# Client 1: power=0.065 → batch_size=8
#   → similarity with global model: 88.39% ✅ included
# Client 2: power=0.096 → batch_size=12
#   → similarity with global model: 91.57% ✅ included
# Client 3: power=0.701 → batch_size=90
#   → similarity with global model: 98.56% ✅ included
# Client 4: power=0.776 → batch_size=100
#   → similarity with global model: 98.77% ✅ included
# Client 5: power=0.079 → batch_size=10
#   → similarity with global model: 89.91% ✅ included
# Client 6: power=0.677 → batch_size=87
#   → similarity with global model: 98.66% ✅ included
# Client 7: power=0.123 → batch_size=15
#   → similarity with global model: 92.95% ✅ included
# Client 8: power=0.641 → batch_size=82
#   → similarity with global model: 98.51% ✅ included
# Client 9: power=0.474 → batch_size=61
#   → similarity with global model: 98.04% ✅ included
#
# Global Accuracy         : 92.04%
# Selected clients        : 10/10
# Comm Volume             : 0.81 MB
# Simulated Net Time      : 0.04 s
# Server Aggregation Time : 0.0013 s
#
# === Running Federated Training with MGD ===
#
# === Round 1 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: -18.00% ❌ excluded
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 60.28% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 69.49% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 65.72% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: -72.88% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 21.00% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -112.07% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -1286.11% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 19.46% ❌ excluded
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: -27.01% ❌ excluded
#
# Global Accuracy         : 80.88%
# Selected clients        : 4/10
# Comm Volume             : 0.33 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0013 s
#
# === Round 2 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 34.13% ❌ excluded
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 82.50% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 86.34% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 84.43% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: -31.97% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 64.37% ❌ excluded
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -70.63% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -1350.53% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 64.07% ❌ excluded
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 22.09% ❌ excluded
#
# Global Accuracy         : 85.74%
# Selected clients        : 3/10
# Comm Volume             : 0.24 MB
# Simulated Net Time      : 0.01 s
# Server Aggregation Time : 0.0010 s
#
# === Round 3 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 47.89% ❌ excluded
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 88.70% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 91.48% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 90.09% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: -9.41% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 75.03% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -58.67% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -1194.10% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 74.70% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 38.56% ❌ excluded
#
# Global Accuracy         : 88.22%
# Selected clients        : 5/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0011 s
#
# === Round 4 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 59.50% ❌ excluded
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 92.76% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 94.78% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 93.82% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: -3.20% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 83.77% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -48.02% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -1005.24% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 82.81% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 48.65% ❌ excluded
#
# Global Accuracy         : 89.52%
# Selected clients        : 5/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0016 s
#
# === Round 5 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 65.50% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 94.19% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 95.81% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 95.03% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 4.50% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 87.08% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -37.03% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -826.99% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 86.38% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 54.44% ❌ excluded
#
# Global Accuracy         : 90.53%
# Selected clients        : 6/10
# Comm Volume             : 0.49 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0013 s
#
# === Round 6 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 68.47% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 95.12% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 96.43% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 95.79% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 8.24% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 89.34% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -31.89% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -894.75% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 88.28% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 62.15% ❌ excluded
#
# Global Accuracy         : 91.31%
# Selected clients        : 6/10
# Comm Volume             : 0.49 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0012 s
#
# === Round 7 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 72.58% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 95.57% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 96.62% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 96.13% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 10.85% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 90.17% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -21.41% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -794.81% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 89.14% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 63.57% ❌ excluded
#
# Global Accuracy         : 91.92%
# Selected clients        : 6/10
# Comm Volume             : 0.49 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0012 s
#
# === Round 8 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 74.20% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 95.81% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 96.72% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 96.43% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 24.61% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 90.79% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -19.71% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -1098.03% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 90.09% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 66.73% ✅ included
#
# Global Accuracy         : 92.41%
# Selected clients        : 7/10
# Comm Volume             : 0.57 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 9 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 77.20% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 95.99% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 97.02% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 96.64% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 24.46% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 91.52% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -8.74% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -874.59% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 91.15% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 69.38% ✅ included
#
# Global Accuracy         : 92.90%
# Selected clients        : 7/10
# Comm Volume             : 0.57 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 10 ===
# Client 0: power=0.202 → batch_size=23
#   → similarity with global model: 78.14% ✅ included
# Client 1: power=0.734 → batch_size=85
#   → similarity with global model: 96.30% ✅ included
# Client 2: power=0.857 → batch_size=100
#   → similarity with global model: 97.10% ✅ included
# Client 3: power=0.801 → batch_size=93
#   → similarity with global model: 96.55% ✅ included
# Client 4: power=0.096 → batch_size=11
#   → similarity with global model: 28.05% ❌ excluded
# Client 5: power=0.414 → batch_size=48
#   → similarity with global model: 91.88% ✅ included
# Client 6: power=0.073 → batch_size=8
#   → similarity with global model: -10.60% ❌ excluded
# Client 7: power=0.003 → batch_size=1
#   → similarity with global model: -601.97% ❌ excluded
# Client 8: power=0.410 → batch_size=47
#   → similarity with global model: 91.49% ✅ included
# Client 9: power=0.180 → batch_size=20
#   → similarity with global model: 67.43% ✅ included
#
# Global Accuracy         : 93.34%
# Selected clients        : 7/10
# Comm Volume             : 0.57 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0011 s
#
# === Running Federated Training with ADAM ===
#
# === Round 1 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: -0.68% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 30.99% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 37.50% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 37.72% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 28.41% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 35.75% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 40.61% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: -25.02% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 33.50% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 37.27% ✅ included
#
# Global Accuracy         : 87.37%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0011 s
#
# === Round 2 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 30.27% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 62.92% ❌ excluded
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 69.86% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 70.35% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 59.09% ❌ excluded
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 67.68% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 71.37% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 4.69% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 64.13% ❌ excluded
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 69.45% ✅ included
#
# Global Accuracy         : 90.30%
# Selected clients        : 5/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0013 s
#
# === Round 3 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 41.91% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 72.92% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 79.36% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 79.52% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 69.50% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 77.52% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 80.19% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 20.94% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 75.37% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 78.96% ✅ included
#
# Global Accuracy         : 91.64%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 4 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 50.06% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 77.94% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 83.15% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 82.74% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 74.40% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 81.42% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 84.62% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 32.48% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 79.76% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 83.29% ✅ included
#
# Global Accuracy         : 92.46%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0012 s
#
# === Round 5 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 54.35% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 80.14% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 84.66% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 84.66% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 76.82% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 83.11% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 85.66% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 37.24% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 82.07% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 84.95% ✅ included
#
# Global Accuracy         : 93.11%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0013 s
#
# === Round 6 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 57.64% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 81.53% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 86.00% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 85.44% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 78.83% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 84.77% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 86.98% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 43.19% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 83.36% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 86.07% ✅ included
#
# Global Accuracy         : 93.62%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 7 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 61.10% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 81.92% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 86.84% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 87.15% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 79.42% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 85.12% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 87.24% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 41.70% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 84.82% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 86.54% ✅ included
#
# Global Accuracy         : 94.00%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0010 s
#
# === Round 8 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 62.46% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 83.59% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 87.44% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 87.73% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 81.07% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 86.30% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 88.34% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 46.91% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 84.71% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 87.19% ✅ included
#
# Global Accuracy         : 94.38%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0013 s
#
# === Round 9 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 62.55% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 84.18% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 87.99% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 88.04% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 82.16% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 87.12% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 88.29% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 50.15% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 85.77% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 87.86% ✅ included
#
# Global Accuracy         : 94.73%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0012 s
#
# === Round 10 ===
# Client 0: power=0.076 → batch_size=8
#   → similarity with global model: 64.99% ❌ excluded
# Client 1: power=0.407 → batch_size=45
#   → similarity with global model: 85.01% ✅ included
# Client 2: power=0.771 → batch_size=86
#   → similarity with global model: 88.55% ✅ included
# Client 3: power=0.762 → batch_size=85
#   → similarity with global model: 88.65% ✅ included
# Client 4: power=0.310 → batch_size=34
#   → similarity with global model: 82.96% ✅ included
# Client 5: power=0.653 → batch_size=73
#   → similarity with global model: 87.57% ✅ included
# Client 6: power=0.891 → batch_size=100
#   → similarity with global model: 89.03% ✅ included
# Client 7: power=0.036 → batch_size=4
#   → similarity with global model: 53.54% ❌ excluded
# Client 8: power=0.503 → batch_size=56
#   → similarity with global model: 86.13% ✅ included
# Client 9: power=0.698 → batch_size=78
#   → similarity with global model: 88.03% ✅ included
#
# Global Accuracy         : 95.00%
# Selected clients        : 8/10
# Comm Volume             : 0.65 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0011 s
