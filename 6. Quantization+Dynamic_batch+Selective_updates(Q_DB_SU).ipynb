# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# --------- Minimal MLP Model ----------
class MinimalMLPModel(nn.Module):
    def __init__(self):
        super(MinimalMLPModel, self).__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        return self.net(x)

# --------- Federated Training Utilities ----------
def train(model, loader, optimizer, criterion, epochs=1):
    model.train()
    for _ in range(epochs):
        for x, y in loader:
            optimizer.zero_grad()
            loss = criterion(model(x), y)
            loss.backward()
            optimizer.step()

def evaluate(model, loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for x, y in loader:
            preds = model(x).argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    return correct / total

def similarity_score(state1, state2):
    norm_diff = 0.0
    norm_ref = 0.0
    for k in state1:
        diff = state1[k] - state2[k]
        norm_diff += torch.norm(diff).item()
        norm_ref += torch.norm(state2[k]).item()
    return 1 - (norm_diff / norm_ref)

# --------- INT8 Quantization Utilities ----------
def quantize_to_int8(tensor):
    scale = tensor.abs().max() / 127.0
    if scale == 0:
        return torch.zeros_like(tensor, dtype=torch.int8), scale
    q_tensor = (tensor / scale).round().clamp(-128, 127).to(torch.int8)
    return q_tensor, scale

def dequantize_from_int8(q_tensor, scale):
    return q_tensor.to(torch.float32) * scale

def quantize_state(state_dict):
    return {k: quantize_to_int8(v) for k, v in state_dict.items()}

def dequantize_state(quantized_state):
    return {k: dequantize_from_int8(v[0], v[1]) for k, v in quantized_state.items()}

# --------- Main Federated Learning Process ----------
def federated_training(
        optimizer_name='adam',
        num_clients=10,
        max_batch_size=100,
        rounds=10,
        bandwidth_mb_per_s=20
    ):
    client_powers = torch.rand(num_clients)
    max_power = client_powers.max()

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    full_dataset = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
    client_data = random_split(full_dataset, [len(full_dataset)//num_clients]*num_clients)

    global_model = MinimalMLPModel()
    criterion = nn.CrossEntropyLoss()

    global_accs, comm_volumes, agg_times, net_times, conv_speeds = [], [], [], [], []
    prev_global_acc = 0.0

    total_params = sum(p.numel() for p in global_model.parameters())
    print(f"\n=== Running Federated Training with {optimizer_name.upper()} (INT8 Quantization) ===")
    for rnd in range(1, rounds+1):
        print(f"\n=== Round {rnd} ===")
        selected_states = []

        inclusion_threshold = 0.20 if rnd == 1 else 0.65

        for i in range(num_clients):
            ratio = (client_powers[i] / max_power).item()
            batch_size = max(1, int(ratio * max_batch_size))
            print(f"Client {i}: power={client_powers[i]:.3f} → batch_size={batch_size}")

            local_model = MinimalMLPModel()
            local_model.load_state_dict(global_model.state_dict())

            if optimizer_name == 'adam':
                optimizer = optim.Adam(local_model.parameters(), lr=0.001)
            elif optimizer_name == 'sgd':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.0)
            elif optimizer_name == 'nag':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.9, nesterov=True)
            elif optimizer_name == 'mgd':
                optimizer = optim.SGD(local_model.parameters(), lr=0.001, momentum=0.99)
            else:
                raise ValueError(f"Unknown optimizer: {optimizer_name}")

            train_loader = DataLoader(client_data[i], batch_size=batch_size, shuffle=True)
            train(local_model, train_loader, optimizer, criterion, epochs=1)

            sim = similarity_score(local_model.state_dict(), global_model.state_dict())
            print(f"  → similarity with global model: {sim:.2%}", end='')

            if sim > inclusion_threshold:
                print(" ✅ included")
                q_state = quantize_state(local_model.state_dict())
                selected_states.append(q_state)
            else:
                print(" ❌ excluded")

        sent_clients = len(selected_states)
        comm_mb = sent_clients * total_params * 1 / 1e6  # 1 byte per parameter (int8)
        net_time = comm_mb / bandwidth_mb_per_s

        start = time.perf_counter()
        new_state = {}
        for key in global_model.state_dict().keys():
            # Aggregate dequantized tensors
            deq_tensors = [dequantize_state(qs)[key] for qs in selected_states]
            stack = torch.stack(deq_tensors, dim=0)
            new_state[key] = stack.mean(dim=0)
        global_model.load_state_dict(new_state)
        agg_time = time.perf_counter() - start

        test_ds = datasets.MNIST(root="./data", train=False, download=True, transform=transform)
        test_loader = DataLoader(test_ds, batch_size=64)
        global_acc = evaluate(global_model, test_loader)

        global_accs.append(global_acc)
        comm_volumes.append(comm_mb)
        net_times.append(net_time)
        agg_times.append(agg_time)
        if rnd > 1:
            conv_speeds.append(global_acc - prev_global_acc)
        prev_global_acc = global_acc

        print(f"\nGlobal Accuracy         : {global_acc:.2%}")
        print(f"Selected clients        : {sent_clients}/{num_clients}")
        print(f"Comm Volume             : {comm_mb:.2f} MB")
        print(f"Simulated Net Time      : {net_time:.2f} s")
        print(f"Server Aggregation Time : {agg_time:.4f} s")

    rounds_idx = list(range(1, rounds+1))



if __name__ == '__main__':
    for opt in ['sgd', 'mgd', 'nag', 'adam']:
        federated_training(
            optimizer_name=opt,
            num_clients=10,
            max_batch_size=100,
            rounds=10,
            bandwidth_mb_per_s=20
        )
# Out:
# === Running Federated Training with SGD (INT8 Quantization) ===
#
# === Round 1 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 78.15% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 97.72% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 97.14% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 96.65% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 97.76% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 95.47% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 97.71% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 95.80% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 95.49% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.61% ✅ included
#
# Global Accuracy         : 41.73%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0105 s
#
# === Round 2 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 78.73% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 97.58% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 96.97% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 96.40% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 97.64% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 95.10% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 97.59% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 95.47% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 95.10% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.56% ✅ included
#
# Global Accuracy         : 64.09%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0052 s
#
# === Round 3 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 80.78% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 97.53% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 96.91% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 96.32% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 97.58% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 95.07% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 97.53% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 95.42% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 95.07% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.51% ✅ included
#
# Global Accuracy         : 74.41%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0036 s
#
# === Round 4 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 83.30% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 97.70% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 97.15% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 96.61% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 97.74% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 95.53% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 97.70% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 95.79% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 95.51% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.60% ✅ included
#
# Global Accuracy         : 79.40%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0046 s
#
# === Round 5 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 85.73% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 98.01% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 97.55% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 97.08% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 98.04% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 96.16% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 98.02% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 96.37% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 96.16% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.78% ✅ included
#
# Global Accuracy         : 81.88%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0035 s
#
# === Round 6 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 87.76% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 98.32% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 97.94% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 97.54% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 98.35% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 96.77% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 98.33% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 96.92% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 96.77% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 98.97% ✅ included
#
# Global Accuracy         : 83.38%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0055 s
#
# === Round 7 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 89.38% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 98.58% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 98.25% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 97.92% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 98.61% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 97.26% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 98.59% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 97.38% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 97.27% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 99.13% ✅ included
#
# Global Accuracy         : 84.58%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0045 s
#
# === Round 8 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 90.74% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 98.78% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 98.51% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 98.21% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 98.81% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 97.66% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 98.79% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 97.74% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 97.66% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 99.25% ✅ included
#
# Global Accuracy         : 85.57%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0038 s
#
# === Round 9 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 91.74% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 98.94% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 98.70% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 98.44% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 98.97% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 97.96% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 98.95% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 98.03% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 97.98% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 99.35% ✅ included
#
# Global Accuracy         : 86.28%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0040 s
#
# === Round 10 ===
# Client 0: power=0.054 → batch_size=6
#   → similarity with global model: 92.63% ✅ included
# Client 1: power=0.549 → batch_size=61
#   → similarity with global model: 99.07% ✅ included
# Client 2: power=0.434 → batch_size=48
#   → similarity with global model: 98.86% ✅ included
# Client 3: power=0.370 → batch_size=41
#   → similarity with global model: 98.63% ✅ included
# Client 4: power=0.552 → batch_size=62
#   → similarity with global model: 99.09% ✅ included
# Client 5: power=0.270 → batch_size=30
#   → similarity with global model: 98.21% ✅ included
# Client 6: power=0.545 → batch_size=61
#   → similarity with global model: 99.08% ✅ included
# Client 7: power=0.292 → batch_size=32
#   → similarity with global model: 98.26% ✅ included
# Client 8: power=0.268 → batch_size=30
#   → similarity with global model: 98.21% ✅ included
# Client 9: power=0.887 → batch_size=100
#   → similarity with global model: 99.43% ✅ included
#
# Global Accuracy         : 86.64%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0037 s
#
# === Running Federated Training with MGD (INT8 Quantization) ===
#
# === Round 1 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 63.89% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 67.30% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -121.82% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 47.22% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 2.90% ❌ excluded
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: -9.06% ❌ excluded
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 47.12% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: -7.52% ❌ excluded
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -194.83% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 63.43% ✅ included
#
# Global Accuracy         : 83.52%
# Selected clients        : 5/10
# Comm Volume             : 0.25 MB
# Simulated Net Time      : 0.01 s
# Server Aggregation Time : 0.0024 s
#
# === Round 2 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 88.44% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 89.37% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -46.36% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 82.40% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 60.37% ❌ excluded
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 51.71% ❌ excluded
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 82.18% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 48.89% ❌ excluded
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -97.44% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 87.73% ✅ included
#
# Global Accuracy         : 88.40%
# Selected clients        : 5/10
# Comm Volume             : 0.25 MB
# Simulated Net Time      : 0.01 s
# Server Aggregation Time : 0.0022 s
#
# === Round 3 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 93.62% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 94.40% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -45.55% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 90.07% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 73.15% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 64.78% ❌ excluded
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 90.11% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 64.13% ❌ excluded
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -86.89% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 93.38% ✅ included
#
# Global Accuracy         : 90.21%
# Selected clients        : 6/10
# Comm Volume             : 0.31 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0041 s
#
# === Round 4 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 95.46% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 96.09% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -31.46% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 93.21% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 80.50% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 72.71% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 93.16% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 71.19% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -87.28% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 95.36% ✅ included
#
# Global Accuracy         : 91.60%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0032 s
#
# === Round 5 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 96.25% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 96.69% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -21.93% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 94.38% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 85.51% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 76.47% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 94.65% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 77.74% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -76.47% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 96.28% ✅ included
#
# Global Accuracy         : 91.87%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0032 s
#
# === Round 6 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 96.68% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 96.96% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -14.18% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 94.83% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 87.10% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 80.04% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 95.24% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 79.80% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -63.00% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 96.70% ✅ included
#
# Global Accuracy         : 92.76%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0032 s
#
# === Round 7 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 97.01% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 97.02% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -5.18% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 95.00% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 87.91% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 81.89% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 95.56% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 82.50% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -55.92% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 97.07% ✅ included
#
# Global Accuracy         : 93.22%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0033 s
#
# === Round 8 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 97.25% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 97.34% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -4.34% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 95.50% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 88.97% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 82.68% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 95.70% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 83.68% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -51.76% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 96.98% ✅ included
#
# Global Accuracy         : 93.40%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0033 s
#
# === Round 9 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 97.16% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 97.39% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -12.74% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 95.60% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 88.72% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 84.05% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 95.87% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 84.02% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -58.42% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 97.35% ✅ included
#
# Global Accuracy         : 93.72%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0029 s
#
# === Round 10 ===
# Client 0: power=0.639 → batch_size=95
#   → similarity with global model: 97.39% ✅ included
# Client 1: power=0.666 → batch_size=100
#   → similarity with global model: 97.36% ✅ included
# Client 2: power=0.057 → batch_size=8
#   → similarity with global model: -7.45% ❌ excluded
# Client 3: power=0.475 → batch_size=71
#   → similarity with global model: 95.81% ✅ included
# Client 4: power=0.234 → batch_size=35
#   → similarity with global model: 89.81% ✅ included
# Client 5: power=0.184 → batch_size=27
#   → similarity with global model: 85.20% ✅ included
# Client 6: power=0.474 → batch_size=71
#   → similarity with global model: 95.75% ✅ included
# Client 7: power=0.181 → batch_size=27
#   → similarity with global model: 84.69% ✅ included
# Client 8: power=0.045 → batch_size=6
#   → similarity with global model: -56.63% ❌ excluded
# Client 9: power=0.622 → batch_size=93
#   → similarity with global model: 97.44% ✅ included
#
# Global Accuracy         : 93.94%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0034 s
#
# === Running Federated Training with NAG (INT8 Quantization) ===
#
# === Round 1 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 71.85% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 87.86% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 85.46% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -46.96% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 63.81% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 79.28% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 84.96% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 81.22% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 76.71% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 67.08% ✅ included
#
# Global Accuracy         : 81.66%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0035 s
#
# === Round 2 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 84.63% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 92.75% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 91.66% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -32.11% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 79.54% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 88.73% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 91.32% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 89.62% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 87.36% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 81.81% ✅ included
#
# Global Accuracy         : 86.35%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0038 s
#
# === Round 3 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 91.33% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 96.23% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 95.72% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -16.82% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 87.44% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 93.95% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 95.47% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 94.48% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 93.12% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 89.30% ✅ included
#
# Global Accuracy         : 87.97%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0037 s
#
# === Round 4 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 93.92% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 97.42% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 97.07% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -9.80% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 90.76% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 95.82% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 96.91% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 96.19% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 95.22% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 92.37% ✅ included
#
# Global Accuracy         : 89.06%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0048 s
#
# === Round 5 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 95.20% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 97.99% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 97.72% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -10.26% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 92.48% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 96.76% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 97.60% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 97.00% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 96.27% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 93.96% ✅ included
#
# Global Accuracy         : 89.82%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0049 s
#
# === Round 6 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 95.92% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 98.34% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 98.04% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -5.52% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 93.63% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 97.27% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 97.95% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 97.50% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 96.82% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 94.92% ✅ included
#
# Global Accuracy         : 90.28%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0036 s
#
# === Round 7 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 96.42% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 98.57% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 98.26% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -2.07% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 94.37% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 97.57% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 98.21% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 97.77% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 97.23% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 95.54% ✅ included
#
# Global Accuracy         : 90.62%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0046 s
#
# === Round 8 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 96.71% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 98.66% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 98.43% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: 0.59% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 94.83% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 97.75% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 98.39% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 97.95% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 97.49% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 95.99% ✅ included
#
# Global Accuracy         : 90.81%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0051 s
#
# === Round 9 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 96.99% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 98.74% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 98.47% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: -2.44% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 95.19% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 97.96% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 98.50% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 98.10% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 97.65% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 96.35% ✅ included
#
# Global Accuracy         : 91.12%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0035 s
#
# === Round 10 ===
# Client 0: power=0.280 → batch_size=40
#   → similarity with global model: 97.19% ✅ included
# Client 1: power=0.692 → batch_size=100
#   → similarity with global model: 98.85% ✅ included
# Client 2: power=0.601 → batch_size=86
#   → similarity with global model: 98.56% ✅ included
# Client 3: power=0.006 → batch_size=1
#   → similarity with global model: 0.74% ❌ excluded
# Client 4: power=0.175 → batch_size=25
#   → similarity with global model: 95.43% ✅ included
# Client 5: power=0.421 → batch_size=60
#   → similarity with global model: 98.07% ✅ included
# Client 6: power=0.586 → batch_size=84
#   → similarity with global model: 98.57% ✅ included
# Client 7: power=0.463 → batch_size=66
#   → similarity with global model: 98.18% ✅ included
# Client 8: power=0.361 → batch_size=52
#   → similarity with global model: 97.77% ✅ included
# Client 9: power=0.220 → batch_size=31
#   → similarity with global model: 96.52% ✅ included
#
# Global Accuracy         : 91.29%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0057 s
#
# === Running Federated Training with ADAM (INT8 Quantization) ===
#
# === Round 1 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 29.98% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 34.76% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 2.19% ❌ excluded
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 35.00% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 17.51% ❌ excluded
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 30.20% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 35.97% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 38.90% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 25.92% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 34.94% ✅ included
#
# Global Accuracy         : 90.22%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0036 s
#
# === Round 2 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 72.29% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 76.87% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 44.19% ❌ excluded
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 75.75% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 61.09% ❌ excluded
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 73.04% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 77.77% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 80.23% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 68.16% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 77.42% ✅ included
#
# Global Accuracy         : 92.17%
# Selected clients        : 8/10
# Comm Volume             : 0.41 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0052 s
#
# === Round 3 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 78.29% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 81.45% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 54.70% ❌ excluded
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 81.72% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 66.96% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 77.88% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 82.15% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 85.23% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 74.80% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 82.07% ✅ included
#
# Global Accuracy         : 92.94%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0034 s
#
# === Round 4 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 79.91% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 83.66% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 57.97% ❌ excluded
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 83.28% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 70.59% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 79.59% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 83.84% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 85.85% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 77.04% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 83.68% ✅ included
#
# Global Accuracy         : 93.91%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0044 s
#
# === Round 5 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 81.71% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 84.61% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 60.92% ❌ excluded
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 84.69% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 73.49% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 81.73% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 85.15% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 87.11% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 79.34% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 84.24% ✅ included
#
# Global Accuracy         : 94.59%
# Selected clients        : 9/10
# Comm Volume             : 0.46 MB
# Simulated Net Time      : 0.02 s
# Server Aggregation Time : 0.0037 s
#
# === Round 6 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 83.24% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 85.76% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 66.45% ✅ included
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 85.49% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 74.88% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 82.80% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 86.10% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 87.61% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 80.73% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 85.72% ✅ included
#
# Global Accuracy         : 95.01%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0052 s
#
# === Round 7 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 83.98% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 86.00% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 67.34% ✅ included
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 86.79% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 76.55% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 84.17% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 87.05% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 88.81% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 82.22% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 85.97% ✅ included
#
# Global Accuracy         : 95.35%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0039 s
#
# === Round 8 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 85.01% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 87.02% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 69.24% ✅ included
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 87.00% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 78.43% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 83.92% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 88.02% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 88.90% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 82.90% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 87.06% ✅ included
#
# Global Accuracy         : 95.69%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0057 s
#
# === Round 9 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 85.32% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 87.64% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 70.43% ✅ included
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 88.27% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 78.93% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 85.38% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 88.43% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 89.52% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 83.84% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 88.02% ✅ included
#
# Global Accuracy         : 95.95%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0050 s
#
# === Round 10 ===
# Client 0: power=0.428 → batch_size=44
#   → similarity with global model: 86.16% ✅ included
# Client 1: power=0.616 → batch_size=64
#   → similarity with global model: 88.27% ✅ included
# Client 2: power=0.105 → batch_size=10
#   → similarity with global model: 72.73% ✅ included
# Client 3: power=0.645 → batch_size=67
#   → similarity with global model: 88.40% ✅ included
# Client 4: power=0.192 → batch_size=20
#   → similarity with global model: 80.50% ✅ included
# Client 5: power=0.445 → batch_size=46
#   → similarity with global model: 86.17% ✅ included
# Client 6: power=0.691 → batch_size=72
#   → similarity with global model: 88.64% ✅ included
# Client 7: power=0.957 → batch_size=100
#   → similarity with global model: 90.00% ✅ included
# Client 8: power=0.331 → batch_size=34
#   → similarity with global model: 84.12% ✅ included
# Client 9: power=0.617 → batch_size=64
#   → similarity with global model: 88.07% ✅ included
#
# Global Accuracy         : 96.25%
# Selected clients        : 10/10
# Comm Volume             : 0.51 MB
# Simulated Net Time      : 0.03 s
# Server Aggregation Time : 0.0042 s
